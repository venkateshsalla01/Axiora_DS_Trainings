# %% [markdown]
# **Assignment 4**
#
# 1. Given a list of numbers, create a function to find the sum of all positive numbers
#
# 2. Write a python function to check if a given string is a palindrome
#
# 3. Create a function that takes a list of strings and returns the list sorted alphabetically.
#
# 4. Implement a function to find the square of each element in a given list.
#
# 5. Calculate the area of a triangle given its base and height using a function.
